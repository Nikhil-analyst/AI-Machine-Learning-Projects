# %% [markdown]
# ## Dog Breed Prediction

# %% [markdown]
# In this project, we will see how to use Keras and TensorFlow to build, train, and test a Convolutional Neural Network capable of identifying the breed of a dog in a supplied image. This is a supervised learning problem, specifically a multiclass classification problem.

# %%
# Important library imports
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

from tqdm import tqdm
from keras.preprocessing import image
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Importing required libraries.

# %%
# Read the labels.csv file and checking shape and records
labels_all = pd.read_csv("../input/dogbreedidfromcomp/labels.csv")
print(labels_all.shape)
labels_all.head()
# Out:
# (10222, 2)
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %% [markdown]
# Loading the labels data into dataframe and viewing it. Here we analysed that labels contains 10222 rows and 2 columns.

# %%
# Visualize the number of each breeds
breeds_all = labels_all["breed"]
breed_counts = breeds_all.value_counts()
breed_counts.head()
# Out:
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
# Name: breed, dtype: int64

# %% [markdown]
# Here we are finding out the count per class i.e. total data in each class using value_counts() function.

# %%
# Selecting first 3 breeds (Limitation due to computation power)
CLASS_NAMES = ['scottish_deerhound','maltese_dog','bernese_mountain_dog']
labels = labels_all[(labels_all['breed'].isin(CLASS_NAMES))]
labels = labels.reset_index()
labels.head()
# Out:
#    index                                id                 breed
# 0      9  0042188c895a2f14ef64a918ed9c7b64    scottish_deerhound
# 1     12  00693b8bc2470375cc744a6391d397ec           maltese_dog
# 2     79  01e787576c003930f96c966f9c3e1d44    scottish_deerhound
# 3     90  022b34fd8734b39995a9f38a4f3e7b6b           maltese_dog
# 4    118  02d54f0dfb40038765e838459ae8c956  bernese_mountain_dog

# %% [markdown]
# We will work on only 3 breeds due to limited computational power. You can consider more classes as per your system computational power.

# %%
# Creating numpy matrix with zeros
X_data = np.zeros((len(labels), 224, 224, 3), dtype='float32')
# One hot encoding
Y_data = label_binarize(labels['breed'], classes = CLASS_NAMES)

# Reading and converting image to numpy array and normalizing dataset
for i in tqdm(range(len(labels))):
    img = image.load_img('../input/dogbreedidfromcomp/train/%s.jpg' % labels['id'][i], target_size=(224, 224))
    img = image.img_to_array(img)
    x = np.expand_dims(img.copy(), axis=0)
    X_data[i] = x / 255.0
    
# Printing train image and one hot encode shape & size
print('\nTrain Images shape: ',X_data.shape,' size: {:,}'.format(X_data.size))
print('One-hot encoded output shape: ',Y_data.shape,' size: {:,}'.format(Y_data.size))
# Out:
# 100%|██████████| 357/357 [00:03<00:00, 104.16it/s]
# Train Images shape:  (357, 224, 224, 3)  size: 53,738,496
# One-hot encoded output shape:  (357, 3)  size: 1,071

# %% [markdown]
# As we are working with the classification dataset first we need to one hot encode the target value i.e. the classes. After that we will read images and convert them into numpy array and finally normalizing the array.

# %%
# Building the Model
model = Sequential()

model.add(Conv2D(filters = 64, kernel_size = (5,5), activation ='relu', input_shape = (224,224,3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 32, kernel_size = (3,3), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 16, kernel_size = (7,7), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 8, kernel_size = (5,5), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(64, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(len(CLASS_NAMES), activation = "softmax"))

model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 220, 220, 64)      4864
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 108, 108, 32)      18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 16)        25104
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 24, 24, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 8)         3208
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 8)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               102528
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 162,619
# Trainable params: 162,619
# Non-trainable params: 0
# _________________________________________________________________
# User settings:
#
#    KMP_AFFINITY=granularity=fine,verbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='verbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2022-01-20 05:30:14.166217: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).

# %% [markdown]
# After defining the network architecture we found out the total parameters as 162,619.

# %%
# Splitting the data set into training and testing data sets
X_train_and_val, X_test, Y_train_and_val, Y_test = train_test_split(X_data, Y_data, test_size = 0.1)
# Splitting the training data set into training and validation data sets
X_train, X_val, Y_train, Y_val = train_test_split(X_train_and_val, Y_train_and_val, test_size = 0.2)

# %% [markdown]
# After defining the network architecture we will start with splitting the test and train data then dividing train data in train and validation data.

# %%
# Training the model
epochs = 100
batch_size = 128

history = model.fit(X_train, Y_train, batch_size = batch_size, epochs = epochs, 
                    validation_data = (X_val, Y_val))
# Out:
# 2022-01-20 05:30:31.257012: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2/2 [==============================] - 16s 7s/step - loss: 4.8937 - accuracy: 0.3438 - val_loss: 4.8722 - val_accuracy: 0.3692
# Epoch 2/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.8669 - accuracy: 0.3516 - val_loss: 4.8467 - val_accuracy: 0.3692
# Epoch 3/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.8405 - accuracy: 0.3594 - val_loss: 4.8215 - val_accuracy: 0.3846
# Epoch 4/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.8148 - accuracy: 0.3633 - val_loss: 4.7958 - val_accuracy: 0.3846
# Epoch 5/100
# 2/2 [==============================] - 10s 6s/step - loss: 4.7891 - accuracy: 0.3867 - val_loss: 4.7703 - val_accuracy: 0.4000
# Epoch 6/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.7645 - accuracy: 0.4023 - val_loss: 4.7455 - val_accuracy: 0.3846
# Epoch 7/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.7396 - accuracy: 0.4023 - val_loss: 4.7205 - val_accuracy: 0.4000
# Epoch 8/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.7150 - accuracy: 0.4102 - val_loss: 4.6953 - val_accuracy: 0.4154
# Epoch 9/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.6892 - accuracy: 0.4102 - val_loss: 4.6701 - val_accuracy: 0.4000
# Epoch 10/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.6639 - accuracy: 0.4219 - val_loss: 4.6448 - val_accuracy: 0.4462
# Epoch 11/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.6387 - accuracy: 0.4375 - val_loss: 4.6188 - val_accuracy: 0.4615
# Epoch 12/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.6132 - accuracy: 0.4375 - val_loss: 4.5931 - val_accuracy: 0.4769
# Epoch 13/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.5868 - accuracy: 0.4414 - val_loss: 4.5676 - val_accuracy: 0.4923
# Epoch 14/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.5601 - accuracy: 0.4609 - val_loss: 4.5409 - val_accuracy: 0.4923
# Epoch 15/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.5331 - accuracy: 0.4570 - val_loss: 4.5131 - val_accuracy: 0.5077
# Epoch 16/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.5054 - accuracy: 0.4648 - val_loss: 4.4848 - val_accuracy: 0.5077
# Epoch 17/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.4762 - accuracy: 0.4727 - val_loss: 4.4554 - val_accuracy: 0.5231
# Epoch 18/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.4467 - accuracy: 0.4805 - val_loss: 4.4248 - val_accuracy: 0.5231
# Epoch 19/100
# 2/2 [==============================] - 10s 6s/step - loss: 4.4141 - accuracy: 0.4961 - val_loss: 4.3917 - val_accuracy: 0.5231
# Epoch 20/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.3817 - accuracy: 0.5195 - val_loss: 4.3576 - val_accuracy: 0.5077
# Epoch 21/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.3463 - accuracy: 0.5547 - val_loss: 4.3222 - val_accuracy: 0.5692
# Epoch 22/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.3073 - accuracy: 0.5820 - val_loss: 4.2802 - val_accuracy: 0.5692
# Epoch 23/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.2667 - accuracy: 0.5625 - val_loss: 4.2350 - val_accuracy: 0.5692
# Epoch 24/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.2199 - accuracy: 0.6250 - val_loss: 4.1922 - val_accuracy: 0.6154
# Epoch 25/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.1735 - accuracy: 0.7266 - val_loss: 4.1400 - val_accuracy: 0.7077
# Epoch 26/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.1231 - accuracy: 0.7227 - val_loss: 4.0861 - val_accuracy: 0.7538
# Epoch 27/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.0700 - accuracy: 0.7422 - val_loss: 4.0287 - val_accuracy: 0.8154
# Epoch 28/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.0207 - accuracy: 0.7852 - val_loss: 3.9729 - val_accuracy: 0.8000
# Epoch 29/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.9803 - accuracy: 0.7617 - val_loss: 3.9228 - val_accuracy: 0.8000
# Epoch 30/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.9257 - accuracy: 0.7969 - val_loss: 3.8887 - val_accuracy: 0.7846
# Epoch 31/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.8852 - accuracy: 0.7500 - val_loss: 3.8350 - val_accuracy: 0.8154
# Epoch 32/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.8335 - accuracy: 0.8047 - val_loss: 3.7751 - val_accuracy: 0.8308
# Epoch 33/100
# 2/2 [==============================] - 10s 6s/step - loss: 3.7990 - accuracy: 0.8086 - val_loss: 3.7388 - val_accuracy: 0.8308
# Epoch 34/100
# 2/2 [==============================] - 15s 11s/step - loss: 3.7769 - accuracy: 0.7969 - val_loss: 3.7032 - val_accuracy: 0.8308
# Epoch 35/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.7284 - accuracy: 0.8125 - val_loss: 3.6619 - val_accuracy: 0.8000
# Epoch 36/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.7143 - accuracy: 0.8086 - val_loss: 3.6340 - val_accuracy: 0.8462
# Epoch 37/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.6729 - accuracy: 0.8203 - val_loss: 3.6131 - val_accuracy: 0.8000
# Epoch 38/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.6331 - accuracy: 0.8281 - val_loss: 3.5769 - val_accuracy: 0.8154
# Epoch 39/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.6055 - accuracy: 0.8477 - val_loss: 3.5380 - val_accuracy: 0.8154
# Epoch 40/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.5829 - accuracy: 0.8555 - val_loss: 3.5163 - val_accuracy: 0.8000
# Epoch 41/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.5661 - accuracy: 0.8398 - val_loss: 3.5092 - val_accuracy: 0.8000
# Epoch 42/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.5295 - accuracy: 0.8555 - val_loss: 3.4948 - val_accuracy: 0.8462
# Epoch 43/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.5129 - accuracy: 0.8516 - val_loss: 3.4561 - val_accuracy: 0.8308
# Epoch 44/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.5016 - accuracy: 0.8438 - val_loss: 3.4344 - val_accuracy: 0.8000
# Epoch 45/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.4547 - accuracy: 0.8711 - val_loss: 3.4283 - val_accuracy: 0.8462
# Epoch 46/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.4492 - accuracy: 0.8672 - val_loss: 3.4045 - val_accuracy: 0.8308
# Epoch 47/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.4256 - accuracy: 0.8633 - val_loss: 3.3789 - val_accuracy: 0.8462
# Epoch 48/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.4039 - accuracy: 0.8867 - val_loss: 3.3569 - val_accuracy: 0.8462
# Epoch 49/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.3802 - accuracy: 0.8828 - val_loss: 3.3655 - val_accuracy: 0.8308
# Epoch 50/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.3758 - accuracy: 0.8672 - val_loss: 3.3287 - val_accuracy: 0.8462
# Epoch 51/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.3553 - accuracy: 0.8711 - val_loss: 3.3030 - val_accuracy: 0.8462
# Epoch 52/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.3413 - accuracy: 0.8789 - val_loss: 3.3298 - val_accuracy: 0.8308
# Epoch 53/100
# 2/2 [==============================] - 10s 6s/step - loss: 3.3283 - accuracy: 0.8828 - val_loss: 3.2882 - val_accuracy: 0.8308
# Epoch 54/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.2918 - accuracy: 0.8906 - val_loss: 3.2803 - val_accuracy: 0.8462
# Epoch 55/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.2915 - accuracy: 0.8789 - val_loss: 3.2541 - val_accuracy: 0.8462
# Epoch 56/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2932 - accuracy: 0.8867 - val_loss: 3.2495 - val_accuracy: 0.8462
# Epoch 57/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.2596 - accuracy: 0.8984 - val_loss: 3.3023 - val_accuracy: 0.8000
# Epoch 58/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2492 - accuracy: 0.8633 - val_loss: 3.2204 - val_accuracy: 0.8462
# Epoch 59/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2241 - accuracy: 0.9062 - val_loss: 3.2066 - val_accuracy: 0.8462
# Epoch 60/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.1970 - accuracy: 0.8945 - val_loss: 3.2420 - val_accuracy: 0.8154
# Epoch 61/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2113 - accuracy: 0.8672 - val_loss: 3.1877 - val_accuracy: 0.8462
# Epoch 62/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2023 - accuracy: 0.9023 - val_loss: 3.1820 - val_accuracy: 0.8615
# Epoch 63/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.1652 - accuracy: 0.8906 - val_loss: 3.2335 - val_accuracy: 0.8000
# Epoch 64/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.1790 - accuracy: 0.8594 - val_loss: 3.1567 - val_accuracy: 0.8615
# Epoch 65/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.1266 - accuracy: 0.9023 - val_loss: 3.1514 - val_accuracy: 0.8769
# Epoch 66/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.1258 - accuracy: 0.9219 - val_loss: 3.1587 - val_accuracy: 0.8308
# Epoch 67/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.1060 - accuracy: 0.8906 - val_loss: 3.1570 - val_accuracy: 0.8308
# Epoch 68/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.0788 - accuracy: 0.9062 - val_loss: 3.1004 - val_accuracy: 0.8615
# Epoch 69/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.0772 - accuracy: 0.9336 - val_loss: 3.0932 - val_accuracy: 0.8615
# Epoch 70/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.0533 - accuracy: 0.9258 - val_loss: 3.1345 - val_accuracy: 0.8308
# Epoch 71/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.0485 - accuracy: 0.8867 - val_loss: 3.0801 - val_accuracy: 0.8769
# Epoch 72/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.0369 - accuracy: 0.9375 - val_loss: 3.0588 - val_accuracy: 0.8615
# Epoch 73/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.0163 - accuracy: 0.9336 - val_loss: 3.0870 - val_accuracy: 0.8462
# Epoch 74/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.0057 - accuracy: 0.9023 - val_loss: 3.0645 - val_accuracy: 0.8462
# Epoch 75/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9875 - accuracy: 0.9336 - val_loss: 3.0283 - val_accuracy: 0.8615
# Epoch 76/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9779 - accuracy: 0.9414 - val_loss: 3.0391 - val_accuracy: 0.8615
# Epoch 77/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9590 - accuracy: 0.9297 - val_loss: 3.0317 - val_accuracy: 0.8462
# Epoch 78/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.9540 - accuracy: 0.9336 - val_loss: 3.0168 - val_accuracy: 0.8308
# Epoch 79/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9342 - accuracy: 0.9375 - val_loss: 3.0048 - val_accuracy: 0.8615
# Epoch 80/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9261 - accuracy: 0.9219 - val_loss: 3.0004 - val_accuracy: 0.8615
# Epoch 81/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.9053 - accuracy: 0.9453 - val_loss: 2.9844 - val_accuracy: 0.8462
# Epoch 82/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8955 - accuracy: 0.9414 - val_loss: 2.9708 - val_accuracy: 0.8615
# Epoch 83/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8813 - accuracy: 0.9492 - val_loss: 2.9667 - val_accuracy: 0.8615
# Epoch 84/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8746 - accuracy: 0.9492 - val_loss: 2.9590 - val_accuracy: 0.8615
# Epoch 85/100
# 2/2 [==============================] - 10s 6s/step - loss: 2.8606 - accuracy: 0.9453 - val_loss: 2.9657 - val_accuracy: 0.8615
# Epoch 86/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8442 - accuracy: 0.9492 - val_loss: 2.9414 - val_accuracy: 0.8615
# Epoch 87/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8332 - accuracy: 0.9453 - val_loss: 2.9183 - val_accuracy: 0.8615
# Epoch 88/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.8203 - accuracy: 0.9492 - val_loss: 2.9274 - val_accuracy: 0.8615
# Epoch 89/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8153 - accuracy: 0.9336 - val_loss: 2.9248 - val_accuracy: 0.8615
# Epoch 90/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8042 - accuracy: 0.9414 - val_loss: 2.8915 - val_accuracy: 0.8462
# Epoch 91/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.7889 - accuracy: 0.9531 - val_loss: 2.9217 - val_accuracy: 0.8462
# Epoch 92/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.7805 - accuracy: 0.9453 - val_loss: 2.8821 - val_accuracy: 0.8615
# Epoch 93/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.7723 - accuracy: 0.9531 - val_loss: 2.8743 - val_accuracy: 0.8462
# Epoch 94/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.7598 - accuracy: 0.9453 - val_loss: 2.9120 - val_accuracy: 0.8462
# Epoch 95/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.7430 - accuracy: 0.9453 - val_loss: 2.8513 - val_accuracy: 0.8462
# Epoch 96/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.7343 - accuracy: 0.9648 - val_loss: 2.8485 - val_accuracy: 0.8615
# Epoch 97/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.7257 - accuracy: 0.9570 - val_loss: 2.8724 - val_accuracy: 0.8462
# Epoch 98/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.7082 - accuracy: 0.9609 - val_loss: 2.8359 - val_accuracy: 0.8615
# Epoch 99/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.7081 - accuracy: 0.9648 - val_loss: 2.8378 - val_accuracy: 0.8462
# Epoch 100/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.6823 - accuracy: 0.9688 - val_loss: 2.8630 - val_accuracy: 0.8462

# %% [markdown]
# Now we will train our model on 100 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# Here we analyse how the model is learning with each epoch in terms of accuracy.

# %%
Y_pred = model.predict(X_test)
score = model.evaluate(X_test, Y_test)
print('Accuracy over the test set: \n ', round((score[1]*100), 2), '%')
# Out:
# 2/2 [==============================] - 0s 39ms/step - loss: 3.2257 - accuracy: 0.6389
# Accuracy over the test set:
#   63.89 %

# %% [markdown]
# We will use predict function to make predictions using this model also we are finding out the accuracy on the test set.

# %%
# Plotting image to compare
plt.imshow(X_test[1,:,:,:])
plt.show()

# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",labels['breed'][np.argmax(Y_test[1])])
print("Predicted : ",labels['breed'][np.argmax(Y_pred[1])])
# Out:
# Originally :  maltese_dog
# Predicted :  maltese_dog

# %% [markdown]
# Here you can see image with its original and predicted label.

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# We started with downloading the dataset creating the model and finding out the predictions using the model. We can optimize different hyper parameters in order to tune this model for a higher accuracy. This model can be used to predict different breeds of dogs which can be further used by different NGO's working on saving animals and for educational purposes also.
